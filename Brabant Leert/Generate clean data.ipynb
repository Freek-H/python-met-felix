# %%
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DimCustomerCopied.csv', sep='|', header=None)
df = df.drop(columns=[1, 2, 3, 7, 10, 17, 18, 20, 21, 25])
df.columns = ['id', 'first_name', 'middle_name', 'last_name', 'birth_date',
       'marital_status', 'sex', 'email', 'salary', 'total_children',
       'number_children_at_home', 'education', 'occupation',
       'house_owner_flag', 'number_of_cars_owned', 'address', 'phone',
       'date_first_purchase', 'commute_distance']
df.birth_date = pd.to_datetime(df.birth_date)
df.date_first_purchase = pd.to_datetime(df.date_first_purchase)
df
# Out:
#           id first_name middle_name last_name birth_date marital_status sex  \
# 0      11000        Jon           V      Yang 1971-10-06              M   M
# 1      11001     Eugene           L     Huang 1976-05-10              S   M
# 2      11002      Ruben         NaN    Torres 1971-02-09              M   M
# 3      11003    Christy         NaN       Zhu 1973-08-14              S   F
# 4      11004  Elizabeth         NaN   Johnson 1979-08-05              S   F
# ...      ...        ...         ...       ...        ...            ...  ..
# 18479  29479      Tommy           L      Tang 1969-06-30              M   M
# 18480  29480       Nina           W      Raji 1977-05-06              S   F
# 18481  29481       Ivan         NaN      Suri 1965-07-04              S   M
# 18482  29482    Clayton         NaN     Zhang 1964-09-01              M   M
# 18483  29483      Jésus           L   Navarro 1965-06-06              M   M
#
# ...

# %%
df.to_csv('all_cleaned.csv', index=False)

# %%
df['birth_date']
# Out:
# 0       1971-10-06
# 1       1976-05-10
# 2       1971-02-09
# 3       1973-08-14
# 4       1979-08-05
#            ...
# 18479   1969-06-30
# 18480   1977-05-06
# 18481   1965-07-04
# 18482   1964-09-01
# 18483   1965-06-06
# Name: birth_date, Length: 18484, dtype: datetime64[ns]

# %%
df[df.birth_date > datetime(1930, 1, 1)]
# Out:
#           id first_name middle_name last_name birth_date marital_status sex  \
# 0      11000        Jon           V      Yang 1971-10-06              M   M
# 1      11001     Eugene           L     Huang 1976-05-10              S   M
# 2      11002      Ruben         NaN    Torres 1971-02-09              M   M
# 3      11003    Christy         NaN       Zhu 1973-08-14              S   F
# 4      11004  Elizabeth         NaN   Johnson 1979-08-05              S   F
# ...      ...        ...         ...       ...        ...            ...  ..
# 18479  29479      Tommy           L      Tang 1969-06-30              M   M
# 18480  29480       Nina           W      Raji 1977-05-06              S   F
# 18481  29481       Ivan         NaN      Suri 1965-07-04              S   M
# 18482  29482    Clayton         NaN     Zhang 1964-09-01              M   M
# 18483  29483      Jésus           L   Navarro 1965-06-06              M   M
#
# ...

# %%
from datetime import datetime
def calculate_age(birth_date):
    current_date = datetime.now()
    if current_date.month > birth_date.month:
        return current_date.year - birth_date.year
    elif current_date.month == birth_date.month and current_date.day >= birth_date.day:
        return current_date.year - birth_date.year
    else:
        return current_date.year - birth_date.year - 1

# %%
df_age = df.copy()
df_age['age'] = [calculate_age(birth_date) for birth_date in df_age['birth_date']]

# %%
plt.plot(df_age.groupby('age').mean()['salary'])

# %% [markdown]
# # Too high ages due to age of database

# %%
(df.birth_date + (datetime.now() - df.date_first_purchase.max())).dt.normalize()
# Out:
# 0       1979-05-14
# 1       1983-12-17
# 2       1978-09-17
# 3       1981-03-22
# 4       1987-03-13
#            ...
# 18479   1977-02-05
# 18480   1984-12-12
# 18481   1973-02-09
# 18482   1972-04-09
# 18483   1973-01-12
# Name: birth_date, Length: 18484, dtype: datetime64[ns]

# %%
df2 = df.copy()
df2.birth_date = (df2.birth_date + (datetime.now() - df2.date_first_purchase.max())).dt.normalize()
df2.date_first_purchase = (df2.date_first_purchase + (datetime.now() - df2.date_first_purchase.max())).dt.normalize()

# %%
df2[['birth_date', 'date_first_purchase']]
# Out:
#       birth_date date_first_purchase
# 0     1979-05-14          2018-08-27
# 1     1983-12-17          2018-08-23
# 2     1978-09-17          2018-08-15
# 3     1981-03-22          2018-08-06
# 4     1987-03-13          2018-08-31
# ...          ...                 ...
# 18479 1977-02-05          2020-04-12
# 18480 1984-12-12          2021-02-22
# 18481 1973-02-09          2019-03-21
# 18482 1972-04-09          2020-04-26
# 18483 1973-01-12          2020-04-17
#
# [18484 rows x 2 columns]

# %%
df2.birth_date.min(), df2.birth_date.max(), df2.date_first_purchase.min(), df2.date_first_purchase.max()
# Out:
# (Timestamp('1923-09-18 00:00:00'),
#  Timestamp('1994-01-31 00:00:00'),
#  Timestamp('2018-08-06 00:00:00'),
#  Timestamp('2021-09-05 00:00:00'))

# %%
calculate_age(df2.birth_date.max())
# Out:
# 27

# %%
df_age = df2.copy()
df_age['age'] = [calculate_age(birth_date) for birth_date in df_age['birth_date']]

# %%
plt.plot(df_age.groupby('age').mean()['salary'])

# %% [markdown]
# ### That's more like it, now to save the data

# %%
df2.to_csv('all_cleaned_date_corrected.csv', index=False)

# %%
plt.plot(df_age[:102].groupby('age').mean()['salary'])

# %%
plt.hist(sorted(df[:102]['commute_distance'], key=lambda x: int(x.rstrip(' Miles').rstrip('+').split('-')[0])))
# Out:
# (array([13.,  0., 34.,  0.,  0.,  5.,  0., 48.,  0.,  2.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(sorted(df['commute_distance'], key=lambda x: int(x.rstrip(' Miles').rstrip('+').split('-')[0])))
# Out:
# (array([6310.,    0., 3232.,    0.,    0., 3234.,    0., 3214.,    0.,
#         2494.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(df_age[7600:7600+total].groupby('age').mean()['salary'])

# %%
for start in range(0, len(df), 100):
    total = 142
    plt.hist(sorted(df[start:start+total]['commute_distance'], key=lambda x: int(x.rstrip(' Miles').rstrip('+').split('-')[0])))
    plt.title(f"df[{start}:{start + total}]")
    plt.show()

# %%
df2[:102].to_csv('102_cleaned_date_corrected.csv', index=False)
