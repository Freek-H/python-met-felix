# %% [markdown]
# # Importeren

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Data inladen

# %%
df = pd.read_csv('les_data.csv')

# %% [markdown]
# https://duckduckgo.com/?t=ffab&q=how+to+read+csv+with+pandas

# %%
df
# Out:
#         id first_name middle_name last_name  birth_date marital_status sex  \
# 0    11000        Jon           V      Yang  1979-05-14              M   M
# 1    11001     Eugene           L     Huang  1983-12-17              S   M
# 2    11002      Ruben         NaN    Torres  1978-09-17              M   M
# 3    11003    Christy         NaN       Zhu  1981-03-22              S   F
# 4    11004  Elizabeth         NaN   Johnson  1987-03-13              S   F
# ..     ...        ...         ...       ...         ...            ...  ..
# 97   11097      Edwin           R      Nara  1980-05-31              M   M
# 98   11098    Mallory           S     Rubio  1974-06-06              S   F
# 99   11099       Adam         NaN      Ross  1974-04-13              M   M
# 100  11100    Latasha           L   Navarro  1973-10-21              S   F
# 101  11101       Abby           L       Sai  1978-06-13              S   F
#
#                               email  salary  total_children  \
# ...

# %%
print(df)
# Out:
#         id first_name middle_name last_name  birth_date marital_status sex  \
# 0    11000        Jon           V      Yang  1979-05-14              M   M
# 1    11001     Eugene           L     Huang  1983-12-17              S   M
# 2    11002      Ruben         NaN    Torres  1978-09-17              M   M
# 3    11003    Christy         NaN       Zhu  1981-03-22              S   F
# 4    11004  Elizabeth         NaN   Johnson  1987-03-13              S   F
# ..     ...        ...         ...       ...         ...            ...  ..
# 97   11097      Edwin           R      Nara  1980-05-31              M   M
# 98   11098    Mallory           S     Rubio  1974-06-06              S   F
# 99   11099       Adam         NaN      Ross  1974-04-13              M   M
# 100  11100    Latasha           L   Navarro  1973-10-21              S   F
# 101  11101       Abby           L       Sai  1978-06-13              S   F
#
#                               email  salary  total_children  \
# ...

# %% [markdown]
# # Eerste indruk van de data

# %%
df.head()
# Out:
#       id first_name middle_name last_name  birth_date marital_status sex  \
# 0  11000        Jon           V      Yang  1979-05-14              M   M
# 1  11001     Eugene           L     Huang  1983-12-17              S   M
# 2  11002      Ruben         NaN    Torres  1978-09-17              M   M
# 3  11003    Christy         NaN       Zhu  1981-03-22              S   F
# 4  11004  Elizabeth         NaN   Johnson  1987-03-13              S   F
#
#                             email  salary  total_children  \
# 0       jon24@adventure-works.com   90000               2
# 1    eugene10@adventure-works.com   60000               3
# 2     ruben35@adventure-works.com   60000               3
# 3   christy12@adventure-works.com   70000               0
# 4  elizabeth5@adventure-works.com   80000               5
#
#    number_children_at_home  education    occupation  house_owner_flag  \
# 0                        0  Bachelors  Professional                 1
# ...

# %%
df.head(2)
# Out:
#       id first_name middle_name last_name  birth_date marital_status sex  \
# 0  11000        Jon           V      Yang  1979-05-14              M   M
# 1  11001     Eugene           L     Huang  1983-12-17              S   M
#
#                           email  salary  total_children  \
# 0     jon24@adventure-works.com   90000               2
# 1  eugene10@adventure-works.com   60000               3
#
#    number_children_at_home  education    occupation  house_owner_flag  \
# 0                        0  Bachelors  Professional                 1
# 1                        3  Bachelors  Professional                 0
#
#    number_of_cars_owned          address                phone  \
# 0                     0  3761 N. 14th St  1 (11) 500 555-0162
# 1                     1       2243 W St.  1 (11) 500 555-0110
#
#   date_first_purchase commute_distance
# 0          2018-08-27        1-2 Miles
# 1          2018-08-23        0-1 Miles

# %%
df.columns
# Out:
# Index(['id', 'first_name', 'middle_name', 'last_name', 'birth_date',
#        'marital_status', 'sex', 'email', 'salary', 'total_children',
#        'number_children_at_home', 'education', 'occupation',
#        'house_owner_flag', 'number_of_cars_owned', 'address', 'phone',
#        'date_first_purchase', 'commute_distance'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                          int64
# first_name                 object
# middle_name                object
# last_name                  object
# birth_date                 object
# marital_status             object
# sex                        object
# email                      object
# salary                      int64
# total_children              int64
# number_children_at_home     int64
# education                  object
# occupation                 object
# house_owner_flag            int64
# number_of_cars_owned        int64
# address                    object
# phone                      object
# date_first_purchase        object
# commute_distance           object
# dtype: object

# %%
df.min()
# Out:
# C:\Users\freek\AppData\Local\Temp/ipykernel_9920/3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# id                                             11000
# first_name                                      Abby
# last_name                                    Alvarez
# birth_date                                1957-08-01
# marital_status                                     M
# sex                                                F
# email                      abby4@adventure-works.com
# salary                                         10000
# total_children                                     0
# number_children_at_home                            0
# education                                  Bachelors
# occupation                                  Clerical
# ...

# %%
df.max()
# Out:
# C:\Users\freek\AppData\Local\Temp/ipykernel_9920/1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# id                                               11101
# first_name                                       Wyatt
# last_name                                          Zhu
# birth_date                                  1993-09-25
# marital_status                                       S
# sex                                                  M
# email                      wyatt32@adventure-works.com
# salary                                          170000
# total_children                                       5
# number_children_at_home                              5
# education                          Partial High School
# occupation                              Skilled Manual
# ...

# %%
df.mean()
# Out:
# C:\Users\freek\AppData\Local\Temp/ipykernel_9920/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# id                         11050.500000
# salary                     59705.882353
# total_children                 1.558824
# number_children_at_home        0.372549
# house_owner_flag               0.725490
# number_of_cars_owned           1.754902
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\freek\AppData\Local\Temp/ipykernel_9920/3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# id                            29.588849
# salary                     30261.431270
# total_children                 1.309323
# number_children_at_home        0.953592
# house_owner_flag               0.448471
# number_of_cars_owned           0.737084
# dtype: float64

# %%
df.describe()
# Out:
#                  id         salary  total_children  number_children_at_home  \
# count    102.000000     102.000000      102.000000               102.000000
# mean   11050.500000   59705.882353        1.558824                 0.372549
# std       29.588849   30261.431270        1.309323                 0.953592
# min    11000.000000   10000.000000        0.000000                 0.000000
# 25%    11025.250000   40000.000000        0.000000                 0.000000
# 50%    11050.500000   60000.000000        2.000000                 0.000000
# 75%    11075.750000   80000.000000        2.000000                 0.000000
# max    11101.000000  170000.000000        5.000000                 5.000000
#
#        house_owner_flag  number_of_cars_owned
# count        102.000000            102.000000
# mean           0.725490              1.754902
# std            0.448471              0.737084
# min            0.000000              0.000000
# 25%            0.000000              1.000000
# ...

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html

# %%
df.describe(include='all')
# Out:
#                   id first_name middle_name last_name  birth_date  \
# count     102.000000        102          53       102         102
# unique           NaN         96          14        81         102
# top              NaN        Jon           L   Johnson  1979-05-14
# freq             NaN          2          12         3           1
# mean    11050.500000        NaN         NaN       NaN         NaN
# std        29.588849        NaN         NaN       NaN         NaN
# min     11000.000000        NaN         NaN       NaN         NaN
# 25%     11025.250000        NaN         NaN       NaN         NaN
# 50%     11050.500000        NaN         NaN       NaN         NaN
# 75%     11075.750000        NaN         NaN       NaN         NaN
# max     11101.000000        NaN         NaN       NaN         NaN
#
#        marital_status  sex                      email         salary  \
# count             102  102                        102     102.000000
# ...

# %% [markdown]
# # Geslacht en kolommen selecteren

# %%
df['sex']
# Out:
# 0      M
# 1      M
# 2      M
# 3      F
# 4      F
#       ..
# 97     M
# 98     F
# 99     M
# 100    F
# 101    F
# Name: sex, Length: 102, dtype: object

# %%
df[['sex']]
# Out:
#     sex
# 0     M
# 1     M
# 2     M
# 3     F
# 4     F
# ..   ..
# 97    M
# 98    F
# 99    M
# 100   F
# 101   F
#
# [102 rows x 1 columns]

# %%
df[['first_name', 'sex']]
# Out:
#     first_name sex
# 0          Jon   M
# 1       Eugene   M
# 2        Ruben   M
# 3      Christy   F
# 4    Elizabeth   F
# ..         ...  ..
# 97       Edwin   M
# 98     Mallory   F
# 99        Adam   M
# 100    Latasha   F
# 101       Abby   F
#
# [102 rows x 2 columns]

# %%
df[['sex', 'first_name']]
# Out:
#     sex first_name
# 0     M        Jon
# 1     M     Eugene
# 2     M      Ruben
# 3     F    Christy
# 4     F  Elizabeth
# ..   ..        ...
# 97    M      Edwin
# 98    F    Mallory
# 99    M       Adam
# 100   F    Latasha
# 101   F       Abby
#
# [102 rows x 2 columns]

# %% [markdown]
# # Eerste visualisatie

# %%
plt.hist(df['sex'])
plt.title('Histogram van geslacht')
plt.show()

# %%
df['sex'].value_counts()
# Out:
# M    51
# F    51
# Name: sex, dtype: int64

# %% [markdown]
# # Hoe zit het met salarissen?

# %%
plt.hist(df['salary'])
plt.title('Histogram van salaris')
plt.ylabel('Aantal personen')
plt.xlabel('Jaarsalaris [$]')
plt.show()

# %% [markdown]
# # Zijn er verbanden tussen salaris en een van de andere variabelen?

# %%
df.corr()
# Out:
#                                id    salary  total_children  \
# id                       1.000000  0.381543       -0.154234
# salary                   0.381543  1.000000       -0.218209
# total_children          -0.154234 -0.218209        1.000000
# number_children_at_home -0.236158  0.089611        0.434280
# house_owner_flag        -0.000746  0.008583        0.162664
# number_of_cars_owned    -0.227669 -0.003264        0.276698
#
#                          number_children_at_home  house_owner_flag  \
# id                                     -0.236158         -0.000746
# salary                                  0.089611          0.008583
# total_children                          0.434280          0.162664
# number_children_at_home                 1.000000          0.102594
# house_owner_flag                        0.102594          1.000000
# number_of_cars_owned                    0.229801          0.064015
#
#                          number_of_cars_owned
# ...

# %% [markdown]
# # Experimenting

# %%
df2 = df.copy()
df2['birth_date'] = pd.to_datetime(df2['birth_date'])

# %%
df2.corr()
# Out:
#                                id    salary  total_children  \
# id                       1.000000  0.381543       -0.154234
# salary                   0.381543  1.000000       -0.218209
# total_children          -0.154234 -0.218209        1.000000
# number_children_at_home -0.236158  0.089611        0.434280
# house_owner_flag        -0.000746  0.008583        0.162664
# number_of_cars_owned    -0.227669 -0.003264        0.276698
#
#                          number_children_at_home  house_owner_flag  \
# id                                     -0.236158         -0.000746
# salary                                  0.089611          0.008583
# total_children                          0.434280          0.162664
# number_children_at_home                 1.000000          0.102594
# house_owner_flag                        0.102594          1.000000
# number_of_cars_owned                    0.229801          0.064015
#
#                          number_of_cars_owned
# ...

# %%
from datetime import datetime
def calculate_age(birth_date):
    current_date = datetime.now()
    if current_date.month > birth_date.month:
        return current_date.year - birth_date.year
    elif current_date.month == birth_date.month and current_date.day >= birth_date.day:
        return current_date.year - birth_date.year
    else:
        return current_date.year - birth_date.year - 1

# %%
df2['age'] = [calculate_age(birth_date) for birth_date in df2['birth_date']]

# %%
df2.corr()
# Out:
#                                id    salary  total_children  \
# id                       1.000000  0.381543       -0.154234
# salary                   0.381543  1.000000       -0.218209
# total_children          -0.154234 -0.218209        1.000000
# number_children_at_home -0.236158  0.089611        0.434280
# house_owner_flag        -0.000746  0.008583        0.162664
# number_of_cars_owned    -0.227669 -0.003264        0.276698
# age                      0.115680 -0.269650        0.670232
#
#                          number_children_at_home  house_owner_flag  \
# id                                     -0.236158         -0.000746
# salary                                  0.089611          0.008583
# total_children                          0.434280          0.162664
# number_children_at_home                 1.000000          0.102594
# house_owner_flag                        0.102594          1.000000
# number_of_cars_owned                    0.229801          0.064015
# ...

# %%
plt.scatter(df2['age'], df2['salary'])

# %%
plt.plot(df2.groupby('age').mean()['salary'])
